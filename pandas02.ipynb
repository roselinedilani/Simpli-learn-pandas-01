# %% [markdown]
# <a href="https://colab.research.google.com/github/roselinedilani/Simpli-learn-pandas-01/blob/main/pandas02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df_FDNY = pd.read_csv("/content/FDNY.csv")
df_FDNY.head()
# Out:
#                                         FacilityName       FacilityAddress  \
# 0                                       FacilityName       FacilityAddress
# 1                                 Engine 4/Ladder 15       42 South Street
# 2                                Engine 10/Ladder 10    124 Liberty Street
# 3                                           Engine 6     49 Beekman Street
# 4  Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...  100-104 Duane Street
#
#      Borough
# 0    Borough
# 1  Manhattan
# 2  Manhattan
# 3  Manhattan
# 4  Manhattan

# %%
Data_frame_analyze = pd.DataFrame(df_FDNY)
Data_frame_analyze
# Out:
#                                           FacilityName  \
# 0                                         FacilityName
# 1                                   Engine 4/Ladder 15
# 2                                  Engine 10/Ladder 10
# 3                                             Engine 6
# 4    Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# ..                                                 ...
# 214                  Engine 162/Ladder 82/Battalion 23
# 215                               Engine 167/Ladder 87
# 216                               Engine 164/Ladder 84
# 217                          Engine 168/EMS Station 23
# 218                               Engine 151/Ladder 76
#
#               FacilityAddress        Borough
# 0             FacilityAddress        Borough
# 1             42 South Street      Manhattan
# 2          124 Liberty Street      Manhattan
# 3           49 Beekman Street      Manhattan
# 4        100-104 Duane Street      Manhattan
# ...

# %%
Data_frame_analyze.shape
# Out:
# (219, 3)

# %%
Data_frame_analyze.describe
# Out:
# <bound method NDFrame.describe of                                           FacilityName  \
# 0                                         FacilityName
# 1                                   Engine 4/Ladder 15
# 2                                  Engine 10/Ladder 10
# 3                                             Engine 6
# 4    Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# ..                                                 ...
# 214                  Engine 162/Ladder 82/Battalion 23
# 215                               Engine 167/Ladder 87
# 216                               Engine 164/Ladder 84
# 217                          Engine 168/EMS Station 23
# 218                               Engine 151/Ladder 76
#
#               FacilityAddress        Borough
# 0             FacilityAddress        Borough
# 1             42 South Street      Manhattan
# 2          124 Liberty Street      Manhattan
# 3           49 Beekman Street      Manhattan
# ...

# %%
Data_frame_analyze_final = pd.read_csv("/content/FDNY.csv",skiprows = 1)
Data_frame_analyze_final.head()
# Out:
#                                         FacilityName        FacilityAddress  \
# 0                                 Engine 4/Ladder 15        42 South Street
# 1                                Engine 10/Ladder 10     124 Liberty Street
# 2                                           Engine 6      49 Beekman Street
# 3  Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...   100-104 Duane Street
# 4                                           Ladder 8  14 North Moore Street
#
#      Borough
# 0  Manhattan
# 1  Manhattan
# 2  Manhattan
# 3  Manhattan
# 4  Manhattan

# %%
Data_frame_analyze_final.describe
# Out:
# <bound method NDFrame.describe of                                           FacilityName  \
# 0                                   Engine 4/Ladder 15
# 1                                  Engine 10/Ladder 10
# 2                                             Engine 6
# 3    Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 4                                             Ladder 8
# ..                                                 ...
# 213                  Engine 162/Ladder 82/Battalion 23
# 214                               Engine 167/Ladder 87
# 215                               Engine 164/Ladder 84
# 216                          Engine 168/EMS Station 23
# 217                               Engine 151/Ladder 76
#
#               FacilityAddress        Borough
# 0             42 South Street      Manhattan
# 1          124 Liberty Street      Manhattan
# 2           49 Beekman Street      Manhattan
# 3        100-104 Duane Street      Manhattan
# ...

# %%
Data_frame_analyze_final.columns
# Out:
# Index(['FacilityName', 'FacilityAddress', 'Borough'], dtype='object')

# %%
Data_frame_analyze_final.count()
# Out:
# FacilityName       218
# FacilityAddress    218
# Borough            218
# dtype: int64

# %%
Data_frame_analyze_final.dtypes
# Out:
# FacilityName       object
# FacilityAddress    object
# Borough            object
# dtype: object

# %%
borough_info = Data_frame_analyze_final.groupby('Borough')
borough_info.head()
# Out:
#                                           FacilityName  \
# 0                                   Engine 4/Ladder 15
# 1                                  Engine 10/Ladder 10
# 2                                             Engine 6
# 3    Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 4                                             Ladder 8
# 48                    Engine 60/Ladder 17/Battalion 14
# 49                                            Squad 41
# 50                      Engine 71/Ladder 55/Division 6
# 51                                 Engine 50/Ladder 19
# 52                    Engine 92/Ladder 44/Battalion 17
# 82   Engine 207/Ladder 110/Battalion 31/Division 11...
# 83                                          Engine 226
# 84                               Engine 205/Ladder 118
# 85                                          Engine 224
# 86                               Engine 279/Ladder 131
# 148                              Engine 258/Ladder 115
# ...

# %%
borough_info.size()
# Out:
# Borough
# Bronx            34
# Brooklyn         66
# Manhattan        48
# Queens           50
# Staten Island    20
# dtype: int64

# %%
borough_info_mahattan = borough_info.get_group('Manhattan')
borough_info_mahattan
# Out:
#                                          FacilityName  \
# 0                                  Engine 4/Ladder 15
# 1                                 Engine 10/Ladder 10
# 2                                            Engine 6
# 3   Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 4                                            Ladder 8
# 5                                   Engine 9/Ladder 6
# 6                     Engine 15/Ladder 18/Battalion 4
# 7                                 Engine 28/Ladder 11
# 8                                            Engine 5
# 9                                           Engine 55
# 10                               Ladder 20/Division 1
# 11                     Engine 24/Ladder 5/Battalion 2
# 12                                 Engine 33/Ladder 9
# 13                               Ladder 3/Battalion 6
# 14                                           Squad 18
# 15                                Engine 34/Ladder 21
# ...
